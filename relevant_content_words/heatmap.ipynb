# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
corr_jacsts = np.array([[2.12, 0.58, 0.77, 10.30, 3.09, 0.9, 0.84, 75.68, 0.13, 2.19, 3.28, 0.12],
                        [1.62, 2.48, 1.27, 3.18, 7.11, 1.16, 3.93, 69.32, 0.46, 3.58, 5.43, 0.4],
                        [1.54, 2.85, 1.2, 3.31, 8.22, 1.31, 4.17, 66.5, 0.46, 3.71, 6.22, 0.46],
                        [1.66, 3.49, 1.28, 2.66, 7.99, 1.39, 5.93, 65.28, 0.55, 4.77, 4.49, 0.5],
                        [2.41, 4.14, 1.51, 4.7, 1.18, 0.95, 8.29, 67.02, 0.45, 2.74, 6.22, 0.39],
                        [2.72, 4.35, 0.82, 4.14, 0.87, 1.25, 12.79, 66.19, 0.33, 2.4, 3.92, 0.22],
                        [0.4, 11.46, 1.06, 4.1, 1.23, 1.23, 21.46, 49.71, 0.53, 4.54, 3.79, 0.44],
                        [0.61, 1.29, 1.53, 11.4, 5.09, 0.12, 0.49, 71.49, 0.12, 2.39, 5.09, 0.31]])

# %%
df = pd.DataFrame(data = corr_jacsts, index = ['SBERT', 'SimCSE-unsup', 'MixCSE-unsup', 'DiffCSE-unsup', 
                                               'SimCSE-base-sup', ' SimCSE-large-sup', 'Bert-first-last-avg', 
                                               'Prior'], 
                  columns = ['ADJ', 'ADP', 'ADV', 'AUX', 'NUM', 'PROPN', 'PUNCT', 'NOUN', 'SCONJ', 
                             'SYM', 'VERB', 'X'])

# %%
df
# Out:
#                       ADJ    ADP   ADV    AUX   NUM  PROPN  PUNCT   NOUN  \
# SBERT                2.12   0.58  0.77  10.30  3.09   0.90   0.84  75.68
# SimCSE-unsup         1.62   2.48  1.27   3.18  7.11   1.16   3.93  69.32
# MixCSE-unsup         1.54   2.85  1.20   3.31  8.22   1.31   4.17  66.50
# DiffCSE-unsup        1.66   3.49  1.28   2.66  7.99   1.39   5.93  65.28
# SimCSE-base-sup      2.41   4.14  1.51   4.70  1.18   0.95   8.29  67.02
#  SimCSE-large-sup    2.72   4.35  0.82   4.14  0.87   1.25  12.79  66.19
# Bert-first-last-avg  0.40  11.46  1.06   4.10  1.23   1.23  21.46  49.71
# Prior                0.61   1.29  1.53  11.40  5.09   0.12   0.49  71.49
#
#                      SCONJ   SYM  VERB     X
# SBERT                 0.13  2.19  3.28  0.12
# SimCSE-unsup          0.46  3.58  5.43  0.40
# MixCSE-unsup          0.46  3.71  6.22  0.46
# DiffCSE-unsup         0.55  4.77  4.49  0.50
# SimCSE-base-sup       0.45  2.74  6.22  0.39
# ...

# %% [raw]
# ax = sns.heatmap(df, annot = True, fmt=".1f", cmap="Blues", cbar_kws={'label': 'Frequency%'})
# ax.set_title('JACSTS', fontsize = 15)

# %%
corr_QAbot = np.array([[3.12, 3.12, 6.25, 1.56, 0, 4.69,70.31,1.56,0,6.25,3.12],
                       [10, 5, 3.33, 25, 3.33, 0,43.33, 0,1.67, 5, 3.33],
                       [9.09, 3.03, 4.55, 15.15, 4.55, 6.06, 45.45, 0, 3.03, 6.06, 3.03],
                       [11.86, 1.69, 1.69, 13.56, 15.25, 0, 40.68, 0, 5.08, 6.78, 3.39],
                       [0, 3.23, 3.23, 11.29, 11.29, 6.45, 53.23, 0, 0, 8.06, 3.23],
                       [9.68, 3.23, 0, 1.61, 14.52, 6.45, 56.45, 0, 0, 4.84, 3.23],
                       [7.23, 25.3,6.02,2.41, 12.05, 0, 27.71, 12.05, 2.41, 2.41, 2.41],
                       [3.12, 1.56, 21.88, 15.62, 0, 0, 25, 10.94, 0, 20.31, 0]])

# %%
df_1 = pd.DataFrame(data = corr_QAbot, index = ['SBERT', 'SimCSE-unsup', 'MixCSE-unsup', 'DiffCSE-unsup', 
                                               'SimCSE-base-sup', ' SimCSE-large-sup', 'Bert-first-last-avg', 
                                               'Prior'], 
                  columns = ['ADJ', 'ADP', 'AUX', 'NUM', 'PROPN', 'PUNCT', 'NOUN', 'SCONJ', 
                             'SYM', 'VERB', 'X'])

# %%
df_1
# Out:
#                        ADJ    ADP    AUX    NUM  PROPN  PUNCT   NOUN  SCONJ  \
# SBERT                 3.12   3.12   6.25   1.56   0.00   4.69  70.31   1.56
# SimCSE-unsup         10.00   5.00   3.33  25.00   3.33   0.00  43.33   0.00
# MixCSE-unsup          9.09   3.03   4.55  15.15   4.55   6.06  45.45   0.00
# DiffCSE-unsup        11.86   1.69   1.69  13.56  15.25   0.00  40.68   0.00
# SimCSE-base-sup       0.00   3.23   3.23  11.29  11.29   6.45  53.23   0.00
#  SimCSE-large-sup     9.68   3.23   0.00   1.61  14.52   6.45  56.45   0.00
# Bert-first-last-avg   7.23  25.30   6.02   2.41  12.05   0.00  27.71  12.05
# Prior                 3.12   1.56  21.88  15.62   0.00   0.00  25.00  10.94
#
#                       SYM   VERB     X
# SBERT                0.00   6.25  3.12
# SimCSE-unsup         1.67   5.00  3.33
# MixCSE-unsup         3.03   6.06  3.03
# DiffCSE-unsup        5.08   6.78  3.39
# SimCSE-base-sup      0.00   8.06  3.23
#  SimCSE-large-sup    0.00   4.84  3.23
# ...

# %% [raw]
# ax = sns.heatmap(df_1, annot = True, fmt=".1f", cmap="Blues", cbar_kws={'label': 'Frequency%'})
# ax.set_title('QAbot', fontsize = 15)

# %%
corr_jsts = np.array([[4.06, 0.39, 0.13, 0.2, 0.46, 3.47, 0, 0, 85.39, 0, 0.2, 5.7],
                      [1.94, 2.46, 0.32, 0.65, 3.04, 2.4, 0, 0.06, 79.6, 0.13, 0.19, 9.2],
                      [1.88, 2.66, 0.39, 0.84, 2.33, 2.14, 0, 0.06, 81.14, 0.06, 0.19, 8.3],
                      [3.17, 2.78, 0.32, 0.97, 2.26, 2.39, 0, 0.06, 77.23, 0.32, 0.19, 10.28],
                      [6.57, 2.21, 0.2, 0.2, 2.86, 3.45, 0.13, 0, 77.16, 0.07, 0.2, 6.96],
                      [7.79, 1.9, 0.26, 0.39, 2.49, 3.53, 0, 0, 74.8, 0.13, 0, 8.7],
                      [0.42, 18.75, 0.24, 15.85, 0.47, 0.71, 0.12, 0.06, 46.41, 2.61, 0.18, 14.18],
                      [0.56, 9.72, 0, 3.59, 0.93, 0.56, 0, 0, 34.1, 2.48, 0, 48.08]])

# %%
df_2 = pd.DataFrame(data = corr_jsts, index = ['SBERT', 'SimCSE-unsup', 'MixCSE-unsup', 'DiffCSE-unsup', 
                                               'SimCSE-base-sup', ' SimCSE-large-sup', 'Bert-first-last-avg', 
                                               'Prior'], 
                  columns = ['ADJ', 'ADP', 'ADV', 'AUX', 'NUM', 'PROPN', 'PUNCT', 'PRON', 'NOUN', 'SCONJ', 
                             'SYM', 'VERB'])

# %%
df_2
# Out:
#                       ADJ    ADP   ADV    AUX   NUM  PROPN  PUNCT  PRON  \
# SBERT                4.06   0.39  0.13   0.20  0.46   3.47   0.00  0.00
# SimCSE-unsup         1.94   2.46  0.32   0.65  3.04   2.40   0.00  0.06
# MixCSE-unsup         1.88   2.66  0.39   0.84  2.33   2.14   0.00  0.06
# DiffCSE-unsup        3.17   2.78  0.32   0.97  2.26   2.39   0.00  0.06
# SimCSE-base-sup      6.57   2.21  0.20   0.20  2.86   3.45   0.13  0.00
#  SimCSE-large-sup    7.79   1.90  0.26   0.39  2.49   3.53   0.00  0.00
# Bert-first-last-avg  0.42  18.75  0.24  15.85  0.47   0.71   0.12  0.06
# Prior                0.56   9.72  0.00   3.59  0.93   0.56   0.00  0.00
#
#                       NOUN  SCONJ   SYM   VERB
# SBERT                85.39   0.00  0.20   5.70
# SimCSE-unsup         79.60   0.13  0.19   9.20
# MixCSE-unsup         81.14   0.06  0.19   8.30
# DiffCSE-unsup        77.23   0.32  0.19  10.28
# SimCSE-base-sup      77.16   0.07  0.20   6.96
# ...

# %% [raw]
# ax = sns.heatmap(df_2, annot = True, fmt=".1f", cmap="Blues", cbar_kws={'label': 'Frequency%'})
# ax.set_title('JSTS', fontsize = 15)

# %%
f,(ax1,ax2,ax3, axcb) = plt.subplots(1,4, 
            gridspec_kw={'width_ratios':[1,0.98,1,0.03]}, sharey = 'col', figsize = (17,4))

g1 = sns.heatmap(df, annot = True, fmt=".1f", cmap="Blues", cbar = False, ax = ax1)
g1.set_title('JACSTS', fontsize = 15)

g2 = sns.heatmap(df_1, annot = True, fmt=".1f", cmap="Blues", cbar = False, ax = ax2, yticklabels=False)
g2.set_title('QAbot', fontsize = 15)
g2.set_ylabel('')

g3 = sns.heatmap(df_2, annot = True, fmt=".1f", cmap="Blues", ax = ax3, cbar_ax=axcb, 
                 cbar_kws={'label': 'Frequency%'}, yticklabels=False)
g3.set_title('JSTS', fontsize = 15)
g3.set_ylabel('')
plt.savefig('fig2_1.png', bbox_inches = 'tight')
plt.show()
